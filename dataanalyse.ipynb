# %%
import csv
import numpy as np
import pandas as pd
import numpy as np
data = pd.read_csv('C:\\Users\\22798\\Desktop\\python课程设计\\shixiseng_packet_capture\\job_list.csv') 
data.columns = ['ad_type','city','cname','day','deliver','ftype','invite','maxsal','minsal','name','refresh','type','url','uuid']

# %%
data.head()
# Out:
#   ad_type city     cname  day  deliver  ftype  invite  maxsal  minsal  \
# 0       f   武汉      武汉安天    4    False      1   False     120      80
# 1       f   武汉      武汉安天    4    False      1   False     150     100
# 2       f   广州      网易游戏    4    False      1   False     200     100
# 3       f   北京    中科院软件所    4    False      1   False     200     120
# 4       f   深圳  IDataAPI    5    False      1   False     200     100
#
#              name refresh    type  \
# 0         数据挖掘工程师   05-16  intern
# 1         数据挖掘实习生   05-16  intern
# 2    语料数据标注实习生-广州   05-16  intern
# 3           安全工程师   05-16  intern
# 4  自然语言处理（NLP）实习生   05-16  intern
#
#                                                  url              uuid
# 0  https://sxsimg.xiaoyuanzhao.com/company_logo/2...  inn_ighmydzsvyfh
# 1  https://sxsimg.xiaoyuanzhao.com/company_logo/2...  inn_ubeigbjabtyy
# 2  https://sxsimg.xiaoyuanzhao.com/company_logo/2...  inn_l1wby0is47ei
# ...

# %%
data = pd.DataFrame(data)
data
# Out:
#     ad_type city       cname  day  deliver  ftype  invite  maxsal  minsal  \
# 0         f   武汉        武汉安天    4    False      1   False     120      80
# 1         f   武汉        武汉安天    4    False      1   False     150     100
# 2         f   广州        网易游戏    4    False      1   False     200     100
# 3         f   北京      中科院软件所    4    False      1   False     200     120
# 4         f   深圳    IDataAPI    5    False      1   False     200     100
# ..      ...  ...         ...  ...      ...    ...     ...     ...     ...
# 218       f   北京        妙计旅行    5    False      1   False     240     140
# 219       f   北京          百度    5    False      1   False     200     150
# 220       f   北京        Baca    4    False      1   False     370     350
# 221       f   北京        汽车之家    4    False      1   False     180     140
# 222       f   北京  志诺维Genowis    4    False      1   False     300     150
#
#                name refresh    type  \
# 0           数据挖掘工程师   05-16  intern
# ...

# %%
import csv
import numpy as np
import pandas as pd
import numpy as np
data1 = pd.read_csv('C:\\Users\\22798\\Desktop\\python课程设计\\shixiseng_packet_capture\\job_detailed.csv') 
data1.columns = ['address','attraction','chance','city','cname','collected','cuuid','day','degree','delivered','endtime','ftype','iname','industry','info','invited','logo','maxsal','minsal','month','overdue','refresh','reslan','scale','url']

# %%
data1.head()
# Out:
#                                   address                      attraction  \
# 0  湖北省武汉市东湖高新技术开发区关山大道光谷软件园F4栋12层（海康威视大楼）                 弹性工作 周末双休 咖啡下午茶
# 1  湖北省武汉市东湖高新技术开发区关山大道光谷软件园F4栋12层（海康威视大楼）                           弹性工作制
# 2                   广州市天河区科韵路16号信息港E栋网易大厦              网络游戏 知名公司 导师制 免费三餐
# 3                         中关村南四街四号 中科院软件园         舒适办公环境 领先技术水平 优秀团队 科研单位
# 4                深圳市南山区高新南七道深圳软件园T2-B栋611  你将获得持续不断的挑战与能力提升，并与志同道合的伙伴并肩作战
#
#   chance city     cname  collected             cuuid  day degree  delivered  \
# 0     面议   武汉      武汉安天          0  com_uiwrsnm6jy3c    4     本科          0
# 1     面议   武汉      武汉安天          0  com_uiwrsnm6jy3c    4     硕士          0
# 2     面议   广州      网易游戏          0  com_kbk8zgqbm4us    4     本科          0
# 3     面议   北京    中科院软件所          0  com_8i4ilr4stxrj    4     硕士          0
# 4     面议   深圳  IDataAPI          0  com_37mjjm3zhmzr    5     本科          0
#
# ...

# %%
data1 = pd.DataFrame(data1)
data1
# Out:
#                                     address  \
# 0    湖北省武汉市东湖高新技术开发区关山大道光谷软件园F4栋12层（海康威视大楼）
# 1    湖北省武汉市东湖高新技术开发区关山大道光谷软件园F4栋12层（海康威视大楼）
# 2                     广州市天河区科韵路16号信息港E栋网易大厦
# 3                           中关村南四街四号 中科院软件园
# 4                  深圳市南山区高新南七道深圳软件园T2-B栋611
# ..                                      ...
# 218       北京 - 东城区 - 安定门 - 雍和宫国学胡同11号（国学书院）
# 219                        北京市 - 海淀区 - 百度大厦
# 220                           北京市海淀区中关村SOHO
# 221                            北京市海淀区中国电子大厦
# 222                        北京市海淀区四季青路优客工厂3层
#
#                                        attraction chance city       cname  \
# 0                                 弹性工作 周末双休 咖啡下午茶     面议   武汉        武汉安天
# 1                                           弹性工作制     面议   武汉        武汉安天
# 2                              网络游戏 知名公司 导师制 免费三餐     面议   广州        网易游戏
# 3                         舒适办公环境 领先技术水平 优秀团队 科研单位     面议   北京      中科院软件所
# ...
